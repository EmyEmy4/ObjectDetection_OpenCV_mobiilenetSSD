#      ----------------------------- ------ 686.1/840.9 kB 758.5 kB/s eta 0:00:01
#      ------------------------------- ---- 727.0/840.9 kB 752.2 kB/s eta 0:00:01
#      ------------------------------- ---- 727.0/840.9 kB 752.2 kB/s eta 0:00:01
#      --------------------------------- -- 778.2/840.9 kB 768.0 kB/s eta 0:00:01
#      -----------------------------------  819.2/840.9 kB 761.7 kB/s eta 0:00:01
#      ------------------------------------ 840.9/840.9 kB 749.0 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pyyaml>=3.13 (from serial)
#   Obtaining dependency information for pyyaml>=3.13 from https://files.pythonhosted.org/packages/b3/34/65bb4b2d7908044963ebf614fe0fdb080773fc7030d7e39c8d3eddcd4257/PyYAML-6.0.1-cp311-cp311-win_amd64.whl.metadata
#   Downloading PyYAML-6.0.1-cp311-cp311-win_amd64.whl.metadata (2.1 kB)
# Collecting iso8601>=0.1.12 (from serial)
#   Obtaining dependency information for iso8601>=0.1.12 from https://files.pythonhosted.org/packages/12/e4/032a8569b75a79057f0c72b4f4a69434fd21922bce7bfe054e0e9f367861/iso8601-2.0.0-py3-none-any.whl.metadata
#   Downloading iso8601-2.0.0-py3-none-any.whl.metadata (3.6 kB)
# Downloading iso8601-2.0.0-py3-none-any.whl (7.5 kB)
# Downloading PyYAML-6.0.1-cp311-cp311-win_amd64.whl (144 kB)
#    ---------------------------------------- 0.0/144.7 kB ? eta -:--:--
#    ------------------- -------------------- 71.7/144.7 kB ? eta -:--:--
#    ------------------- -------------------- 71.7/144.7 kB ? eta -:--:--
#    ------------------- -------------------- 71.7/144.7 kB ? eta -:--:--
#    ------------------- -------------------- 71.7/144.7 kB ? eta -:--:--
#    ------------------- -------------------- 71.7/144.7 kB ? eta -:--:--
#    ------------------- -------------------- 71.7/144.7 kB ? eta -:--:--
#    ------------------- -------------------- 71.7/144.7 kB ? eta -:--:--
#    ------------------- -------------------- 71.7/144.7 kB ? eta -:--:--
#    ------------------- -------------------- 71.7/144.7 kB ? eta -:--:--
#    ------------------- -------------------- 71.7/144.7 kB ? eta -:--:--
#    ------------------- -------------------- 71.7/144.7 kB ? eta -:--:--
#    ------------------- -------------------- 71.7/144.7 kB ? eta -:--:--
#    ------------------- -------------------- 71.7/144.7 kB ? eta -:--:--
#    ------------------- -------------------- 71.7/144.7 kB ? eta -:--:--
#    ------------------- -------------------- 71.7/144.7 kB ? eta -:--:--
#    ------------------------ -------------- 92.2/144.7 kB 116.5 kB/s eta 0:00:01
#    ------------------------ -------------- 92.2/144.7 kB 116.5 kB/s eta 0:00:01
#    ----------------------------- -------- 112.6/144.7 kB 126.1 kB/s eta 0:00:01
#    ----------------------------- -------- 112.6/144.7 kB 126.1 kB/s eta 0:00:01
#    -------------------------------- ----- 122.9/144.7 kB 122.2 kB/s eta 0:00:01
#    -------------------------------- ----- 122.9/144.7 kB 122.2 kB/s eta 0:00:01
#    -------------------------------------- 144.7/144.7 kB 130.4 kB/s eta 0:00:00
# Building wheels for collected packages: future
#   Building wheel for future (setup.py): started
#   Building wheel for future (setup.py): finished with status 'done'
#   Created wheel for future: filename=future-0.18.3-py3-none-any.whl size=492055 sha256=1d338cf83e87d1d6efdefff5698974abc811299518649926c56eebf2c8214fcc
#   Stored in directory: c:\users\evolv\appdata\local\pip\cache\wheels\da\19\ca\9d8c44cd311a955509d7e13da3f0bea42400c469ef825b580b
# Successfully built future
# Installing collected packages: pyyaml, iso8601, future, serial
# Successfully installed future-0.18.3 iso8601-2.0.0 pyyaml-6.0.1 serial-0.0.97
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2 
import time
import matplotlib.pyplot as plt

import serial
import time



def sent_data():
    value = write_read(num)
    print(value)
config_file ='ssd_mobilenet_v3_large_coco_2020_01_14.pbtxt'
frozen_model = 'frozen_inference_graph.pb'

model=cv2.dnn_DetectionModel(frozen_model,config_file)

classLabels = []
file_name = 'Label.txt'
with open(file_name,'rt') as fpt:
    classLabels = fpt.read().rstrip('\n').split('\n')

print(classLabels)

print(len(classLabels))

model.setInputSize(320,320)
model.setInputScale(1.0/127.5)
model.setInputMean((127.5,127.5,127.5))
model.setInputSwapRB(True)

cap=cv2.VideoCapture(0)

if not cap.isOpened():
    cap = cv2.VideoCapture(0)
if not cap.isOpened():
    raise IOError("Cannot open video")
frame_width  = int(cap.get(3))
frame_height = int(cap.get(4))

size = (frame_width, frame_height) 
    
font_scale = 3
font = cv2.FONT_HERSHEY_PLAIN

while True:
    num = '0'
    ret,frame = cap.read()
    
    ClassIndex, confidence, bbox = model.detect(frame,confThreshold=0.55)
    print(ClassIndex)
    if(len(ClassIndex)!=0):
        for ClassInd, conf, boxes in zip(ClassIndex.flatten(), confidence.flatten(), bbox):
            if(ClassInd<=80):
                cv2.rectangle(frame,boxes,(255, 0, 0), 2 )
                cv2.putText(frame,classLabels[ClassInd-1],(boxes[0]+10,boxes[1]+40), font, fontScale=font_scale,color=(0, 255, 0), thickness=3)
                print(classLabels[ClassInd-1])
                if classLabels[ClassInd-1] == 'animal':
                    print ("Animal Activity Detected...!")
                    num =  '1'
                else :
                    num =  '0'
    cv2.imshow('Show',frame)
    #arduino.write(bytes(num, 'utf-8'))
    #time.sleep(0.0)
    #data = arduino.readline()
    #print(data)
    if cv2.waitKey(2) & 0xFF == ord('q'):
        break
        
cap.release()
cv2.destroyAllWindows()
# Out:
# ['person', 'bicycle', 'car', 'motorbike', 'aeroplane', 'bus', 'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'stop sign', 'parking meter', 'bench', 'animal', 'animal', 'animal', 'animal', 'animal', 'animal', 'animal', 'animal', 'animal', 'animal', 'backpack', 'umbrella', 'handbag', 'tie', 'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball', 'kite', 'baseball bat', 'baseball glove', 'skateboard', 'surfboard', 'tennis racket', 'bottle', 'wine glass', 'cup', 'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple', 'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza', 'donut', 'cake', 'chair', 'sofa', 'pottedplant', 'bed', 'diningtable', 'toilet', 'tvmonitor', 'refrigerator', 'mouse', 'remote', 'keyboard', 'cell phone', 'microwave', 'oven', 'toaster', 'sink', 'laptop', 'book', 'clock', 'vase', 'Mobile Phone', 'teddy bear', 'hair drier', 'toothbrush']
# 80
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [ 1 77  1]
# person
# Mobile Phone
# person
# [1 1]
# person
# person
# [ 1  1 46]
# person
# person
# bowl
# [1 1]
# person
# person
# [1 1]
# person
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [ 1 77]
# person
# Mobile Phone
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [ 1 77]
# person
# Mobile Phone
# [ 1 77]
# person
# Mobile Phone
# [77  1]
# Mobile Phone
# person
# [ 1 77]
# person
# Mobile Phone
# [ 1 77]
# person
# Mobile Phone
# [1]
# person
# [ 1 77]
# person
# Mobile Phone
# [ 1 77]
# person
# Mobile Phone
# [ 1 77]
# person
# Mobile Phone
# [ 1 77]
# person
# Mobile Phone
# [1]
# person
# [1]
# person
# [1]
# person
# [1]
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [ 1 84]
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [ 1 72]
# person
# sink
# [ 1 77 72]
# person
# Mobile Phone
# sink
# [77  1]
# Mobile Phone
# person
# [77  1  1]
# Mobile Phone
# person
# person
# [77  1]
# Mobile Phone
# person
# [ 1 18]
# person
# animal
# Human Activity Detected...!
# [77  1]
# Mobile Phone
# person
# [77]
# Mobile Phone
# [77  1  1]
# Mobile Phone
# person
# person
# [ 1 77  1]
# person
# Mobile Phone
# person
# [1]
# person
# [ 1  1 77]
# person
# person
# Mobile Phone
# [ 1 77  1]
# person
# Mobile Phone
# person
# [ 1 77]
# person
# Mobile Phone
# [1]
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1]
# person
# [1]
# person
# [1]
# person
# [1]
# person
# [1]
# person
# [1]
# person
# [ 1 77]
# person
# Mobile Phone
# ()
# [1]
# person
# [1]
# person
# [1]
# person
# [ 1 77]
# person
# Mobile Phone
# [ 1 77]
# person
# Mobile Phone
# [ 1 77]
# person
# Mobile Phone
# [ 1 77]
# person
# Mobile Phone
# [ 1 77]
# person
# Mobile Phone
# [ 1 77]
# person
# Mobile Phone
# [1]
# person
# [1]
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [ 1 77]
# person
# Mobile Phone
# [ 1 77]
# person
# Mobile Phone
# [ 1 77]
# person
# Mobile Phone
# [ 1 77]
# person
# Mobile Phone
# [ 1 77]
# person
# Mobile Phone
# [ 1 77]
# person
# Mobile Phone
# [77  1]
# Mobile Phone
# person
# [77  1  1]
# Mobile Phone
# person
# person
# [77  1  1]
# Mobile Phone
# person
# person
# [77  1]
# Mobile Phone
# person
# [77  1  1]
# Mobile Phone
# person
# person
# [77  1]
# Mobile Phone
# person
# [77  1  1]
# Mobile Phone
# person
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1  1]
# Mobile Phone
# person
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [1]
# person
# [1]
# person
# [1 1]
# person
# person
# [1]
# person
# [1 1 1]
# person
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1 1]
# person
# person
# person
# [1]
# person
# [1]
# person
# [ 1 72]
# person
# sink
# [ 1 72  1]
# person
# sink
# person
# [72  1]
# sink
# person
# [72  1]
# sink
# person
# [72  1  1]
# sink
# person
# person
# [ 1 72  1]
# person
# sink
# person
# [ 1 72]
# person
# sink
# [ 1 72]
# person
# sink
# [ 1 72]
# person
# sink
# [1]
# person
# [ 1  1 72]
# person
# person
# sink
# [ 1 72]
# person
# sink
# [ 1  1 72]
# person
# person
# sink
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1]
# person
# [1 1]
# person
# person
# [1]
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1]
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1]
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [ 1 72  1]
# person
# sink
# person
# [ 1 72  1  1]
# person
# sink
# person
# person
# [1 1 1]
# person
# person
# person
# [ 1  1  1 72]
# person
# person
# person
# sink
# [1 1 1]
# person
# person
# person
# [1 1 1]
# person
# person
# person
# [1 1]
# person
# person
# [ 1  1 77]
# person
# person
# Mobile Phone
# [1 1]
# person
# person
# [1 1]
# person
# person
# [ 1  1 77]
# person
# person
# Mobile Phone
# [ 1  1 77]
# person
# person
# Mobile Phone
# [ 1  1 77]
# person
# person
# Mobile Phone
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1 1]
# person
# person
# person
# [1 1 1]
# person
# person
# person
# [1 1 1]
# person
# person
# person
# [ 1  1 72  1]
# person
# person
# sink
# person
# [1 1 1]
# person
# person
# person
# [ 1  1 77]
# person
# person
# Mobile Phone
# [1 1]
# person
# person
# [84  1]
# person
# [84  1  1]
# person
# person
# [84  1]
# person
# [84  1]
# person
# [84  1  1]
# person
# person
# [84  1  1]
# person
# person
# [84  1  1]
# person
# person
# [84  1]
# person
# [84  1]
# person
# [84  1]
# person
# [84  1]
# person
# [ 1 84]
# person
# [84]
# [84]
# ()
# [1]
# person
# ()
# [84  1]
# person
# [77  1]
# Mobile Phone
# person
# [ 1 84]
# person
# [77 84  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1  1  1  1]
# Mobile Phone
# person
# person
# person
# person
# [77  1  1  1]
# Mobile Phone
# person
# person
# person
# [1 1 1]
# person
# person
# person
# [1 1 1]
# person
# person
# person
# [1 1 1]
# person
# person
# person
# [1 1 1]
# person
# person
# person
# [1 1 1]
# person
# person
# person
# [1 1 1]
# person
# person
# person
# [1 1 1]
# person
# person
# person
# [ 1  1 72]
# person
# person
# sink
# [ 1  1 72]
# person
# person
# sink
# [1 1]
# person
# person
# [1 1 1]
# person
# person
# person
# [1 1 1]
# person
# person
# person
# [1 1]
# person
# person
# [ 1  1 72]
# person
# person
# sink
# [1 1 1]
# person
# person
# person
# [1 1]
# person
# person
# [1 1 1]
# person
# person
# person
# [1 1 1]
# person
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [ 1  1  1 72]
# person
# person
# person
# sink
# [ 1  1 72  1]
# person
# person
# sink
# person
# [1 1 1]
# person
# person
# person
# [ 1  1 72]
# person
# person
# sink
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1 1]
# person
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1 1]
# person
# person
# person
# [1 1 1]
# person
# person
# person
# [1 1]
# person
# person
# [ 1  1  1 72]
# person
# person
# person
# sink
# [ 1  1  1 72]
# person
# person
# person
# sink
# [72  1  1  1]
# sink
# person
# person
# person
# [72  1  1  1]
# sink
# person
# person
# person
# [77 72]
# Mobile Phone
# sink
# [ 1 77]
# person
# Mobile Phone
# [77]
# Mobile Phone
# [77  1]
# Mobile Phone
# person
# ()
# ()
# [1]
# person
# ()
# ()
# ()
# ()
# ()
# ()
# [1]
# person
# [1]
# person
# ()
# [1]
# person
# ()
# ()
# [1]
# person
# ()
# ()
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1]
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1 1]
# person
# person
# person
# [1 1 1 1]
# person
# person
# person
# person
# [1 1 1]
# person
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1 1]
# person
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [ 1  1 77]
# person
# person
# Mobile Phone
# [ 1 77  1]
# person
# Mobile Phone
# person
# [ 1 77  1]
# person
# Mobile Phone
# person
# [ 1 77  1]
# person
# Mobile Phone
# person
# [ 1 77  1]
# person
# Mobile Phone
# person
# [ 1 77  1]
# person
# Mobile Phone
# person
# [ 1 77  1]
# person
# Mobile Phone
# person
# [ 1 77  1]
# person
# Mobile Phone
# person
# [ 1 77  1]
# person
# Mobile Phone
# person
# [ 1 77  1]
# person
# Mobile Phone
# person
# [ 1 77  1]
# person
# Mobile Phone
# person
# [ 1 77  1]
# person
# Mobile Phone
# person
# [ 1 77  1]
# person
# Mobile Phone
# person
# [ 1  1 77]
# person
# person
# Mobile Phone
# [ 1  1 77]
# person
# person
# Mobile Phone
# [ 1 77  1]
# person
# Mobile Phone
# person
# [ 1 77  1]
# person
# Mobile Phone
# person
# [ 1 77  1]
# person
# Mobile Phone
# person
# [ 1  1 77]
# person
# person
# Mobile Phone
# [ 1  1 77]
# person
# person
# Mobile Phone
# [ 1 77  1]
# person
# Mobile Phone
# person
# [ 1 77  1]
# person
# Mobile Phone
# person
# [ 1 77  1]
# person
# Mobile Phone
# person
# [ 1  1 77]
# person
# person
# Mobile Phone
# [ 1  1 77]
# person
# person
# Mobile Phone
# [ 1  1 77]
# person
# person
# Mobile Phone
# [ 1  1 77]
# person
# person
# Mobile Phone
# [ 1 77  1]
# person
# Mobile Phone
# person
# [ 1  1 77]
# person
# person
# Mobile Phone
# [ 1  1 77]
# person
# person
# Mobile Phone
# [ 1  1 77]
# person
# person
# Mobile Phone
# [ 1 77  1]
# person
# Mobile Phone
# person
# [ 1  1 77]
# person
# person
# Mobile Phone
# [ 1 77  1]
# person
# Mobile Phone
# person
# [ 1 77  1]
# person
# Mobile Phone
# person
# [ 1  1 77]
# person
# person
# Mobile Phone
# [ 1 77  1]
# person
# Mobile Phone
# person
# [ 1  1 77]
# person
# person
# Mobile Phone
# [ 1 77  1]
# person
# Mobile Phone
# person
# [ 1  1 77]
# person
# person
# Mobile Phone
# [ 1  1 77]
# person
# person
# Mobile Phone
# [ 1  1 77]
# person
# person
# Mobile Phone
# [ 1 77  1]
# person
# Mobile Phone
# person
# [ 1 77  1]
# person
# Mobile Phone
# person
# [ 1 77  1]
# person
# Mobile Phone
# person
# [ 1 77  1]
# person
# Mobile Phone
# person
# [ 1 77  1]
# person
# Mobile Phone
# person
# [ 1 77  1]
# person
# Mobile Phone
# person
# [ 1 77  1]
# person
# Mobile Phone
# person
# [ 1 77  1]
# person
# Mobile Phone
# person
# [ 1 77  1]
# person
# Mobile Phone
# person
# [ 1 77  1]
# person
# Mobile Phone
# person
# [ 1 77  1]
# person
# Mobile Phone
# person
# [ 1 77  1]
# person
# Mobile Phone
# person
# [ 1 77  1]
# person
# Mobile Phone
# person
# [ 1 77  1]
# person
# Mobile Phone
# person
# [ 1 77  1]
# person
# Mobile Phone
# person
# [ 1 77  1]
# person
# Mobile Phone
# person
# [ 1 77  1]
# person
# Mobile Phone
# person
# [ 1 77  1]
# person
# Mobile Phone
# person
# [ 1 77  1]
# person
# Mobile Phone
# person
# [ 1 77  1]
# person
# Mobile Phone
# person
# [ 1 77  1]
# person
# Mobile Phone
# person
# [ 1 77  1]
# person
# Mobile Phone
# person
# [ 1 77  1]
# person
# Mobile Phone
# person
# [ 1 77  1]
# person
# Mobile Phone
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [ 1  1 77]
# person
# person
# Mobile Phone
# [ 1  1 77]
# person
# person
# Mobile Phone
# [1 1]
# person
# person
# [ 1 77  1]
# person
# Mobile Phone
# person
# [ 1 77  1]
# person
# Mobile Phone
# person
# [ 1 77  1]
# person
# Mobile Phone
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [ 1  1 77 72]
# person
# person
# Mobile Phone
# sink
# [ 1  1 77]
# person
# person
# Mobile Phone
# [ 1 72  1 65  1]
# person
# sink
# person
# mouse
# person
# [ 1  1 72]
# person
# person
# sink
# [ 1 72  1 77]
# person
# sink
# person
# Mobile Phone
# [77  1  1]
# Mobile Phone
# person
# person
# [ 1  1  1 72]
# person
# person
# person
# sink
# [1 1 1]
# person
# person
# person
# [1 1 1]
# person
# person
# person
# [ 1  1 72]
# person
# person
# sink
# [ 1  1 72]
# person
# person
# sink
# [ 1  1  1 72]
# person
# person
# person
# sink
# [ 1  1  1 72]
# person
# person
# person
# sink
# [ 1  1 72]
# person
# person
# sink
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [ 1  1 72]
# person
# person
# sink
# [ 1  1 72]
# person
# person
# sink
# [ 1 72  1]
# person
# sink
# person
# [77  1  1]
# Mobile Phone
# person
# person
# [77  1  1]
# Mobile Phone
# person
# person
# [77  1]
# Mobile Phone
# person
# [77  1  1]
# Mobile Phone
# person
# person
# [77  1  1]
# Mobile Phone
# person
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1  1]
# Mobile Phone
# person
# person
# [77  1  1]
# Mobile Phone
# person
# person
# [77  1  1]
# Mobile Phone
# person
# person
# [77  1  1]
# Mobile Phone
# person
# person
# [77  1  1]
# Mobile Phone
# person
# person
# [77  1  1  1]
# Mobile Phone
# person
# person
# person
# [77  1  1  1]
# Mobile Phone
# person
# person
# person
# [ 1 77  1  1]
# person
# Mobile Phone
# person
# person
# [ 1 77  1  1]
# person
# Mobile Phone
# person
# person
# [ 1 77  1]
# person
# Mobile Phone
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1 1]
# person
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1]
# person
# [1]
# person
# [1]
# person
# [ 1  1 77]
# person
# person
# Mobile Phone
# [1]
# person
# [1 1]
# person
# person
# [1 1 1]
# person
# person
# person
# [1]
# person
# [1]
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [ 1  1 84]
# person
# person
# [ 1  1 84]
# person
# person
# [1 1]
# person
# person
# [1 1 1 1]
# person
# person
# person
# person
# [ 1 84  1  1]
# person
# person
# person
# [ 1  1  1  1 72]
# person
# person
# person
# person
# sink
# [ 1  1 72  1]
# person
# person
# sink
# person
# [ 1  1 72  1 84]
# person
# person
# sink
# person
# [ 1  1  1 72 84]
# person
# person
# person
# sink
# [ 1  1  1 72]
# person
# person
# person
# sink
# [ 1  1  1 72  1]
# person
# person
# person
# sink
# person
# [ 1  1  1 72]
# person
# person
# person
# sink
# [ 1  1  1 72]
# person
# person
# person
# sink
# [ 1  1  1  1 77]
# person
# person
# person
# person
# Mobile Phone
# [1 1 1 1]
# person
# person
# person
# person
# [1 1 1]
# person
# person
# person
# [1 1 1]
# person
# person
# person
# [1 1 1]
# person
# person
# person
# [ 1  1  1  1 72]
# person
# person
# person
# person
# sink
# [ 1  1  1 72]
# person
# person
# person
# sink
# [ 1  1  1  1 72]
# person
# person
# person
# person
# sink
# [1 1 1 1 1]
# person
# person
# person
# person
# person
# [1 1 1 1]
# person
# person
# person
# person
# [1 1 1]
# person
# person
# person
# [1 1 1 1 1]
# person
# person
# person
# person
# person
# [ 1  1  1  1 72]
# person
# person
# person
# person
# sink
# [1 1 1 1]
# person
# person
# person
# person
# [ 1  1  1  1 72]
# person
# person
# person
# person
# sink
# [ 1  1  1  1 72]
# person
# person
# person
# person
# sink
# [1 1 1 1]
# person
# person
# person
# person
# [1 1 1 1]
# person
# person
# person
# person
# [1 1 1]
# person
# person
# person
# [1 1 1 1]
# person
# person
# person
# person
# [1 1 1 1]
# person
# person
# person
# person
# [ 1  1  1 84]
# person
# person
# person
# [1 1 1]
# person
# person
# person
# [1 1 1]
# person
# person
# person
# [1 1 1 1]
# person
# person
# person
# person
# [1 1 1 1]
# person
# person
# person
# person
# [1 1]
# person
# person
# [1 1 1 1]
# person
# person
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1 1]
# person
# person
# person
# [1 1 1]
# person
# person
# person
# [1 1 1]
# person
# person
# person
# [1 1 1]
# person
# person
# person
# [1 1 1]
# person
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [ 1  1 18]
# person
# person
# animal
# Human Activity Detected...!
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1]
# person
# [1 1]
# person
# person
# [1]
# person
# [1]
# person
# [1]
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [ 1  1 72]
# person
# person
# sink
# [ 1  1 72]
# person
# person
# sink
# [ 1  1 72]
# person
# person
# sink
# [1 1]
# person
# person
# [1 1]
# person
# person
# [ 1  1  1 77]
# person
# person
# person
# Mobile Phone
# [ 1  1  1 77]
# person
# person
# person
# Mobile Phone
# [ 1  1 77]
# person
# person
# Mobile Phone
# [ 1  1 77]
# person
# person
# Mobile Phone
# [ 1  1 77]
# person
# person
# Mobile Phone
# [ 1 18]
# person
# animal
# Human Activity Detected...!
# [1 1]
# person
# person
# [ 1 77  1]
# person
# Mobile Phone
# person
# [ 1 77]
# person
# Mobile Phone
# [ 1 77]
# person
# Mobile Phone
# [ 1 77]
# person
# Mobile Phone
# [ 1 77 18]
# person
# Mobile Phone
# animal
# Human Activity Detected...!
# [ 1 18 77]
# person
# animal
# Human Activity Detected...!
# Mobile Phone
# [ 1 77]
# person
# Mobile Phone
# [ 1 77]
# person
# Mobile Phone
# [ 1 77]
# person
# Mobile Phone
# [ 1 77]
# person
# Mobile Phone
# [ 1 77]
# person
# Mobile Phone
# [1 1]
# person
# person
# [1 1]
# person
# person
# [ 1  1 77  1]
# person
# person
# Mobile Phone
# person
# [1 1 1 1]
# person
# person
# person
# person
# [1 1 1]
# person
# person
# person
# [ 1  1 77  1  1]
# person
# person
# Mobile Phone
# person
# person
# [ 1 18  1]
# person
# animal
# Human Activity Detected...!
# person
# [ 1 18  1 77]
# person
# animal
# Human Activity Detected...!
# person
# Mobile Phone
# [ 1 18 77  1]
# person
# animal
# Human Activity Detected...!
# Mobile Phone
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [ 1  1 18 77]
# person
# person
# animal
# Human Activity Detected...!
# Mobile Phone
# [ 1 77 18  1]
# person
# Mobile Phone
# animal
# Human Activity Detected...!
# person
# [ 1 18]
# person
# animal
# Human Activity Detected...!
# [1]
# person
# [1 1]
# person
# person
# [ 1 18]
# person
# animal
# Human Activity Detected...!
# [ 1 77  1 18]
# person
# Mobile Phone
# person
# animal
# Human Activity Detected...!
# [ 1  1 77]
# person
# person
# Mobile Phone
# [ 1 73  1]
# person
# laptop
# person
# [ 1  1 73]
# person
# person
# laptop
# [1]
# person
# [1 1]
# person
# person
# [ 1  1 18]
# person
# person
# animal
# Human Activity Detected...!
# [1 1]
# person
# person
# [1 1]
# person
# person
# [ 1  1 77]
# person
# person
# Mobile Phone
# [ 1  1 77]
# person
# person
# Mobile Phone
# [ 1 77  1]
# person
# Mobile Phone
# person
# [ 1 77]
# person
# Mobile Phone
# [ 1 77]
# person
# Mobile Phone
# [ 1 77]
# person
# Mobile Phone
# [1]
# person
# [1 1]
# person
# person
# [ 1 77  1]
# person
# Mobile Phone
# person
# [ 1 77]
# person
# Mobile Phone
# [ 1 77]
# person
# Mobile Phone
# [ 1 77]
# person
# Mobile Phone
# [77  1 18]
# Mobile Phone
# person
# animal
# Human Activity Detected...!
# [77  1 18]
# Mobile Phone
# person
# animal
# Human Activity Detected...!
# [ 1 77 18]
# person
# Mobile Phone
# animal
# Human Activity Detected...!
# [ 1 77 18]
# person
# Mobile Phone
# animal
# Human Activity Detected...!
# [ 1 18 77  1]
# person
# animal
# Human Activity Detected...!
# Mobile Phone
# person
# [ 1 77  1]
# person
# Mobile Phone
# person
# [ 1 77  1]
# person
# Mobile Phone
# person
# [ 1 77  1]
# person
# Mobile Phone
# person
# [ 1 77 18]
# person
# Mobile Phone
# animal
# Human Activity Detected...!
# [ 1 77 18]
# person
# Mobile Phone
# animal
# Human Activity Detected...!
# [ 1 77]
# person
# Mobile Phone
# [ 1 77 18]
# person
# Mobile Phone
# animal
# Human Activity Detected...!
# [ 1 77]
# person
# Mobile Phone
# [ 1 77]
# person
# Mobile Phone
# [ 1 77]
# person
# Mobile Phone
# [ 1 77]
# person
# Mobile Phone
# [ 1 77 18]
# person
# Mobile Phone
# animal
# Human Activity Detected...!
# [ 1 77 18]
# person
# Mobile Phone
# animal
# Human Activity Detected...!
# [ 1 77 18]
# person
# Mobile Phone
# animal
# Human Activity Detected...!
# [ 1 77  1 18]
# person
# Mobile Phone
# person
# animal
# Human Activity Detected...!
# [ 1 77  1]
# person
# Mobile Phone
# person
# [ 1 77  1]
# person
# Mobile Phone
# person
# [ 1 77  1 18]
# person
# Mobile Phone
# person
# animal
# Human Activity Detected...!
# [ 1 77  1]
# person
# Mobile Phone
# person
# [ 1 77 18]
# person
# Mobile Phone
# animal
# Human Activity Detected...!
# [ 1 77]
# person
# Mobile Phone
# [ 1  1 77]
# person
# person
# Mobile Phone
# [ 1 77]
# person
# Mobile Phone
# [ 1 77 18]
# person
# Mobile Phone
# animal
# Human Activity Detected...!
# [ 1 77 18]
# person
# Mobile Phone
# animal
# Human Activity Detected...!
# [ 1 77]
# person
# Mobile Phone
# [ 1 77]
# person
# Mobile Phone
# [ 1 77  1]
# person
# Mobile Phone
# person
# [ 1 77 18]
# person
# Mobile Phone
# animal
# Human Activity Detected...!
# [ 1 77]
# person
# Mobile Phone
# [ 1 77  1]
# person
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [ 1 77  1]
# person
# Mobile Phone
# person
# [77  1  1]
# Mobile Phone
# person
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person
# [1 1]
# person
# person

# %%
# Python program to save a
# video using OpenCV


import cv2


# Create an object to read
# from camera
video = cv2.VideoCapture(0)

# We need to check if camera
# is opened previously or not
if (video.isOpened() == False):
	print("Error reading video file")

# We need to set resolutions.
# so, convert them from float to integer.
frame_width = int(video.get(3))
frame_height = int(video.get(4))

size = (frame_width, frame_height)

# Below VideoWriter object will create
# a frame of above defined The output
# is stored in 'filename.avi' file.
result = cv2.VideoWriter('filename.avi',
						cv2.VideoWriter_fourcc(*'MJPG'),
						10, size)
	
while(True):
	ret, frame = video.read()

	if ret == True:

		# Write the frame into the
		# file 'filename.avi'
		result.write(frame)

		# Display the frame
		# saved in the file
		cv2.imshow('Frame', frame)

	 	# Press S on keyboard
		# to stop the process
		if cv2.waitKey(1) & 0xFF == ord('s'):
			break

	 # Break the loop
	else:
		break

# When everything done, release
# the video capture and video
# write objects
video.release()
result.release()
	
# Closes all the frames
cv2.destroyAllWindows()

print("The video was successfully saved")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15696\3817061690.py in <module>
#      25 # a frame of above defined The output
#      26 # is stored in 'filename.avi' file.
# ---> 27 result = cv2.VideoWriter('filename.avi',
#      28                                                 cv2.VideoWriter_fourcc(*'MJPG'),
#      29 						10, size)
#
# KeyboardInterrupt:
